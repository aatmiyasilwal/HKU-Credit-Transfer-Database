# %%
import pandas as pd

# %%
#merging and sorting the file
def merge(file_paths):
    df_list = [pd.read_csv(file) for file in file_paths]
    merged_df = pd.concat(df_list, ignore_index=True)

    merged_df['University'] = merged_df['University'].str.strip()
    merged_df['Exchange-Course-Code'] = merged_df['Exchange-Course-Code'].str.strip()
    merged_df['Exchange-Course-Title'] = merged_df['Exchange-Course-Title'].str.strip()

    merged_df['University'] = merged_df['University'].str.replace(r'^The\s+', '', regex=True)
    # sorted_df = merged_df.sort_values(by='University')
    return merged_df

def sorting(df):
    return df.sort_values(by='University')

# %%
#all files in the database
file_paths = [
    'arts-credit_transfer_database.csv',
    'business-credit_transfer_database.csv',
    'compsci-credit_transfer_database.csv',
    'engg-credit_transfer_database.csv',
    'science-credit_transfer_database.csv',
    'sosci-credit_transfer_database.csv'
]  

df = merge(file_paths)

# %%
# backtracked analysis then cleaning
df.loc[df['University'] == 'Aalto University, School of Science','University'] = 'Aalto University'

df.loc[df['University'] == 'Albert-Ludwigs-Universität Freiburg','University'] = 'Albert-Ludwigs-University Freiburg'
df.loc[df['University'] == 'Albert-Ludwigs-University of Freiburg','University'] = 'Albert-Ludwigs-University Freiburg'
df.loc[df['University'] == 'Albert-Ludwig University of Freiburg','University'] = 'Albert-Ludwigs-University Freiburg'
df.loc[df['University'] == 'Albert-Ludwigs University Freiburg','University'] = 'Albert-Ludwigs-University Freiburg'

df.loc[df['University'] == 'Auckland (University of)','University'] = 'University of Auckland'

df.loc[df['University'] == 'Bremen City University of Applied Sciences','University'] = 'Bremen University of Applied Sciences'

df.loc[df['University'] == 'Aberdeen (University of)','University'] = 'University of Aberdeen'
df.loc[df['University'] == 'Alberta (University of)','University'] = 'University of Alberta'
df.loc[df['University'] == 'Bristol (University of)','University'] = 'University of Bristol'
df.loc[df['University'] == 'British Columbia (University of)','University'] = 'University of British Columbia'
df.loc[df['University'] == 'Calgary (University of)','University'] = 'University of Calgary'
df.loc[df['University'] == 'Cambridge (University of)','University'] = 'University of Cambridge'
df.loc[df['University'] == 'Connecticut (University of)','University'] = 'University of Connecticut'
df.loc[df['University'] == 'Chicago (University of)','University'] = 'University of Chicago'
df.loc[df['University'] == 'Edinburgh (University of)','University'] = 'University of Edinburgh'
df.loc[df['University'] == 'Edinburgh (University of )','University'] = 'University of Edinburgh'
df.loc[df['University'] == 'Georgia (University of)','University'] = 'University of Georgia'
df.loc[df['University'] == 'Glasgow (University of)','University'] = 'University of Glasgow'
df.loc[df['University'] == 'Helsinki (University of)','University'] = 'University of Helsinki'
df.loc[df['University'] == 'Illinois at Urbana-Champaign (University of)','University'] = 'University of Illinois at Urbana-Champaign'
df.loc[df['University'] == 'University of Illinois at Urbanna-Champaign','University'] = 'University of Illinois at Urbana-Champaign'
df.loc[df['University'] == 'Kansas (University of)','University'] = 'University of Kansas'
df.loc[df['University'] == 'Kyushu Univeristy','University'] = 'Kyushu University'
df.loc[df['University'] == 'Leicester (University of)','University'] = 'University of Leicester'
df.loc[df['University'] == 'Lund University (School of Economics and Management)','University'] = 'Lund University'
df.loc[df['University'] == 'Leeds (University of )','University'] = 'University of Leeeds'
df.loc[df['University'] == 'Helsinki (University of)','University'] = 'University of Helsinki'
df.loc[df['University'] == 'Manchester (University of)','University'] = 'University of Manchester'
df.loc[df['University'] == 'Maryland (University of)','University'] = 'University of Maryland'
df.loc[df['University'] == 'Melbourne (University of)','University'] = 'University of Melbourne'
df.loc[df['University'] == 'New South Wales (University of)','University'] = 'University of New South Wales'
df.loc[df['University'] == 'North Carolina (University of)','University'] = 'University of North Carolina'
df.loc[df['University'] == 'Nottingham (University of)','University'] = 'University of Nottingham'
df.loc[df['University'] == 'Oxford (University of)','University'] = 'University of Oxford'
df.loc[df['University'] == 'Pittsburgh (University of)','University'] = 'University of Pittsburgh'
df.loc[df['University'] == 'Queensland (University of)','University'] = 'University of Queensland'
df.loc[df['University'] == 'Sheffield (University of)','University'] = 'University of Sheffield'
df.loc[df['University'] == 'Strathclyde (University of)','University'] = 'University of Strathclyde'
df.loc[df['University'] == 'Sydney (University of)','University'] = 'University of Sydney'
df.loc[df['University'] == 'Sydney (University of )','University'] = 'University of Sydney'
df.loc[df['University'] == 'Tokyo (University of)','University'] = 'University of Tokyo'
df.loc[df['University'] == 'Toronto (University of)','University'] = 'University of Toronto'
df.loc[df['University'] == 'Waterloo (University of)','University'] = 'University of Waterloo'
df.loc[df['University'] == 'Virginia (University of)','University'] = 'University of Virginia'
df.loc[df['University'] == 'Wisconsin-Madison (University of)','University'] = 'University of Wisconsin-Madison'
df.loc[df['University'] == 'Western Australia (University of)','University'] = 'University of Western Australia'
df.loc[df['University'] == 'Western (University of)','University'] = 'Western University'
df.loc[df['University'] == 'North Carolina (University of) at Chapel Hill','University'] = 'University of North Carolina at Chapel Hill'

df.loc[df['University'] == 'SOAS University of London','University'] = 'SOAS, University of London'
df.loc[df['University'] == 'SOAS University of London (School of Oriental and African Studies)','University'] = 'SOAS University of London'

df.loc[df['University'] == "Queen's University",'University'] = "Queen's University, Kingston"
df.loc[df['University'] == "Queen’s University, Kingston",'University'] = "Queen's University, Kingston"

df.loc[df['University'] == "Shanghai Jiaotong University",'University'] = "Shanghai Jiao Tong University"

df.loc[df['University'] == 'California (University of), Berkeley','University'] = 'University of California, Berkeley'
df.loc[df['University'] == 'California (University of), Davis','University'] = 'University of California, Davis'
df.loc[df['University'] == 'California (University of), Irvine','University'] = 'University of California, Irvine'
df.loc[df['University'] == 'California (University of), Los Angeles','University'] = 'University of California, Los Angeles'
df.loc[df['University'] == 'California (University of), San Diego','University'] = 'University of California, San Diego'
df.loc[df['University'] == 'California (University of), Santa Barbara','University'] = 'University of California, Santa Barbara'
df.loc[df['University'] == 'California, (University of), Santa Barbara','University'] = 'University of California, Santa Barbara'
df.loc[df['University'] == 'University of California Riverside'] = 'University of California, Riverside'

df.loc[df['University'] == 'Danish School of Media & Journalism', 'University'] = 'Danish School of Media and Journalism'
df.loc[df['University'] == 'Eberhard-Karls-Universitat Tubingen', 'University'] = 'Eberhard Karls Universitat Tubingen'
df.loc[df['University'] == 'Ewha Womans University', 'University'] = 'Ewha Womens University'
df.loc[df['University'] == 'Yonsei Unviersity', 'University'] = 'Yonsei University'

df.loc[df['University'] == 'University of LaUSnne', 'University'] = 'University of Lausanne'
df.loc[df['University'] == 'University of Hawaiʻi at Mānoa', 'University'] = 'University of Hawaii at Manoa'
df.loc[df['University'] == 'University of Durham / Durham University', 'University'] = 'University of Durham'
df.loc[df['University'] == 'Universite Lumiere Lyon II', 'University'] = 'Universite Lumiere Lyon 2'
df.loc[df['University'] == 'Université Jean Moulin Lyon 3', 'University'] = 'Université Jean Moulin - Lyon 3'
df.loc[df['University'] == 'University College Dublin, UCD Quinn School of Business', 'University'] = 'University College Dublin'
df.loc[df['University'] == 'Virginia Tech', 'University'] = 'Virginia Polytechnic Institute and State University'
df.loc[df['University'] == 'University of the Chicago', 'University'] = 'University of Chicago'
df.loc[df['University'] == 'Pusan National Universeity', 'University'] = 'Pusan National University'

df.loc[df['University'] == 'Rutgers, the State University of New Jersey', 'University'] = 'Rutgers, The State University of New Jersey'
df.loc[df['University'] == 'Rutgers University', 'University'] = 'Rutgers, The State University of New Jersey'
df.loc[df['University'] == 'Flinders University of South Australia', 'University'] = 'Flinders University'
df.loc[df['University'] == 'Macquaire University', 'University'] = 'Macquarie University'
df.loc[df['University'] == 'Eberhard Karls Universität Tübingen', 'University'] = 'Eberhard Karls Universitat Tubingen'

df.loc[df['University'] == 'Université Jean Moulin - Lyon 3', 'University'] = 'University Jean Moulin - Lyon 3'
df.loc[df['University'] == 'Université Lumière (Lyon II)', 'University'] = 'University Lumiere Lyon 2'
df.loc[df['University'] == 'Université Paris-Dauphine', 'University'] = 'University of Paris-Dauphine'

df.loc[df['University'] == "Institut d'Etudes Politiques de Paris", 'University'] = 'Sciences Po Paris'
df.loc[df['University'] == "Institut d'Etudes Politiques de Paris (Sciences Po Paris)", 'University'] = 'Sciences Po Paris'
df.loc[df['University'] == "Institut d'Etudes Politiques de Paris (Sciences Po)", 'University'] = 'Sciences Po Paris'

df.loc[df['University'] == "Ludwig-Maximilians Universitat Munchen", 'University'] = 'Ludwig Maximilian University of Munich'
df.loc[df['University'] == "Ludwig-Maximilians-Universität München", 'University'] = 'Ludwig Maximilian University of Munich'
df.loc[df['University'] == "`", 'University'] = 'University of Illinois at Urbana-Champaign'

df.loc[df['University'] == '''London School of Economics and 
Political Science''', 'University'] = 'London School of Economics and Political Science'
df.loc[df['University'] == """International University of Applied 
Sciences Bad Honnef - Bonn""", 'University'] = 'International University of Applied Sciences Bad Honnef - Bonn'

df = df[df['University'] != 'Unknown']
# drop Unknown

df = sorting(df)

# %%
df.to_csv("merged-credit_transfer_database.csv", index=False)
